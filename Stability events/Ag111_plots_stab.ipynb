# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot(x, y, title):
    plt.plot(x, y, 'o')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(title)
    plt.show()

# %% [markdown]
# # Increasing events with Ag111, superficial source

# %%
events = [5000, 10000, 50000, 100000,500000,1000000, 5000000] #keV

#data 
SSB = [0.324902,0.333705,0.348724,0.352487,0.358498,0.361539,0.361915,]#Gy-1 Mbp-1
SSBp = [0.0414769,0.0319505,0.0255814,0.0225613,0.022723,0.0226977,0.0228001,]#Gy-1 Mbp-1
dSSB = [0.0103692,0.00887513,0.0111919,0.0115903,0.0106838,0.0107474,0.010685,]#Gy-1 Mbp-1
SSBtotal = [0.376748,0.37453,0.385498,0.386638,0.391905,0.394984,0.3954,] #Gy-1 Mbp-1

DSB = [0.0120974,0.0150877,0.0158107,0.0160141,0.0161402,0.0159103,0.0156967,]#Gy-1 Mbp-1
DSBp = [0.00518461,0.00355005,0.00248708,0.00194646,0.00202412,0.00256392,0.00227597,]#Gy-1 Mbp-1
DSBpp =[0,0.000887513,0.00106589,0.00106171,0.00183051,0.00187026,0.00198994,]#Gy-1 Mbp-1
DSBtotal = [0.017282,0.0195253,0.0193637,0.0190222,0.0199948,0.0203445,0.0199626,]#Gy-1 Mbp-1

SSB_direct  = [0.0449333,0.0399381,0.0373062,0.0386638,0.0406584,0.0401885,0.0404218,]#Gy-1 Mbp-1
SSB_indirect  = [0.312805,0.322167,0.334868,0.334791,0.337888,0.341396,0.341455,]#Gy-1 Mbp-1
SSB_mixed  = [0.0190102,0.0124252,0.0133237,0.0131829,0.0133592,0.0133991,0.0135225,]#Gy-1 Mbp-1

DSB_direct  = [0.00345641,0.00266254,0.00142119,0.00185799,0.0016193,0.00159806,0.00159687,]#Gy-1 Mbp-1
DSB_indirect  = [0.0103692,0.0115377,0.00923773,0.0083167,0.00848371,0.00891225,0.00847216,]#Gy-1 Mbp-1
DSB_mixed  = [0,0.000887513,0.000888243,0.00079628,0.00107366,0.00116781,0.0012424,]#Gy-1 Mbp-1
DSB_hybrid  = [0.00345641,0.00443756,0.00781654,0.00805127,0.00881813,0.0086664,0.00865115,]#Gy-1 Mbp-1

# %% [markdown]
# ## SSB plot against number of events

# %%
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('Analysis of the results stability with increasing events,\n superficial  distribution', fontsize = 20)

#SSB
axs[0, 0].plot(events, SSB, label='SSB')
axs[0, 0].plot(events, SSBp, label='SSB+')
axs[0, 0].plot(events, dSSB, label='double SSB')
axs[0, 0].plot(events, SSBtotal, label='total SSB')
axs[0, 0].set_title('SSB damage complexity classification', fontsize = 14)
axs[0, 0].legend(fontsize = 10)
axs[0, 0].set_xscale('log')

#DSB
axs[0, 1].plot(events, DSB, label='DSB')
axs[0, 1].plot(events, DSBp, label='DSB+')
axs[0, 1].plot(events, DSBpp, label='DSB++')
axs[0, 1].plot(events, DSBtotal, label='total DSB')
axs[0, 1].set_title('DSB damage complexity classification', fontsize = 14)
axs[0, 1].legend(fontsize = 10)
axs[0, 1].set_xscale('log')

#SSB source
axs[1, 0].plot(events, SSB_direct, label='Direct SSB')
axs[1, 0].plot(events, SSB_indirect, label='Indirect SSB')
axs[1, 0].plot(events, SSB_mixed, label='Mixed SSB')
axs[1, 0].set_title('SSB damage source classification', fontsize = 14)
axs[1, 0].legend(fontsize = 10)
axs[1, 0].set_xscale('log')

#DSB source
axs[1, 1].plot(events, DSB_direct, label='Direct DSB')
axs[1, 1].plot(events, DSB_indirect, label='Indirect DSB')
axs[1, 1].plot(events, DSB_mixed, label='Mixed DSB')
axs[1, 1].plot(events, DSB_hybrid, label='Hybrid DSB')
axs[1, 1].set_title('DSB damage source classification', fontsize = 14)
axs[1, 1].legend(fontsize = 10)
axs[1, 1].set_xscale('log')


#set labels
xlabel = 'Number of events'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)

# Set the filename and format
filename = "AgStability_Supeerficial.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')


plt.show()

# %% [markdown]
# # Increasing events with Ag111, volume source

# %%
events = [1000, 10000, 100000,1000000] #keV

#data 
SSB = [0.429024,0.352207,0.352207,0.355938]#Gy-1 Mbp-1
SSBp = [0.0147939,0.0240635,0.0240635,0.0228503]#Gy-1 Mbp-1
dSSB = [0,0.0119998,0.0119998,0.0112711]#Gy-1 Mbp-1
SSBtotal = [0.443818,0.38827,0.38827,0.390059] #Gy-1 Mbp-1

DSB = [0.00739697,0.0148083,0.0148083,0.0160889]#Gy-1 Mbp-1
DSBp = [0,0.00165955,0.00165955,0.00232717]#Gy-1 Mbp-1
DSBpp =[0,0.00178721,0.00178721,0.00203156]#Gy-1 Mbp-1
DSBtotal = [0.00739697,0.018255,0.018255,0.0204477]#Gy-1 Mbp-1

SSB_direct  = [0.0591757,0.0412334,0.0412334,0.0400274]#Gy-1 Mbp-1
SSB_indirect  = [0.369848,0.332356,0.332356,0.336119]#Gy-1 Mbp-1
SSB_mixed  = [0.0147939,0.0146806,0.0146806,0.0139127]#Gy-1 Mbp-1

DSB_direct  = [0,0.00185103,0.00185103,0.0019435]#Gy-1 Mbp-1
DSB_indirect  = [0,0.0084254,0.0084254,0.00859167]#Gy-1 Mbp-1
DSB_mixed  = [0,0.000893603,0.000893603,0.00123906]#Gy-1 Mbp-1
DSB_hybrid  = [0.00739697,0.00708499,0.00708499,0.00867344]#Gy-1 Mbp-1

# %%
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('Analysis of the results stability with increasing events,\n volume distribution', fontsize = 20)

#SSB
axs[0, 0].plot(events, SSB, label='SSB')
axs[0, 0].plot(events, SSBp, label='SSB+')
axs[0, 0].plot(events, dSSB, label='double SSB')
axs[0, 0].plot(events, SSBtotal, label='total SSB')
axs[0, 0].set_title('SSB damage complexity classification', fontsize = 14)
axs[0, 0].legend(fontsize = 10)
axs[0, 0].set_xscale('log')

#DSB
axs[0, 1].plot(events, DSB, label='DSB')
axs[0, 1].plot(events, DSBp, label='DSB+')
axs[0, 1].plot(events, DSBpp, label='DSB++')
axs[0, 1].plot(events, DSBtotal, label='total DSB')
axs[0, 1].set_title('DSB damage complexity classification', fontsize = 14)
axs[0, 1].legend(fontsize = 10)
axs[0, 1].set_xscale('log')

#SSB source
axs[1, 0].plot(events, SSB_direct, label='Direct SSB')
axs[1, 0].plot(events, SSB_indirect, label='Indirect SSB')
axs[1, 0].plot(events, SSB_mixed, label='Mixed SSB')
axs[1, 0].set_title('SSB damage source classification', fontsize = 14)
axs[1, 0].legend(fontsize = 10)
axs[1, 0].set_xscale('log')

#DSB source
axs[1, 1].plot(events, DSB_direct, label='Direct DSB')
axs[1, 1].plot(events, DSB_indirect, label='Indirect DSB')
axs[1, 1].plot(events, DSB_mixed, label='Mixed DSB')
axs[1, 1].plot(events, DSB_hybrid, label='Hybrid DSB')
axs[1, 1].set_title('DSB damage source classification', fontsize = 14)
axs[1, 1].legend(fontsize = 10)
axs[1, 1].set_xscale('log')


#set labels
xlabel = 'Number of events'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)

# Set the filename and format
filename = "AgStability_Volume.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')


plt.show()
