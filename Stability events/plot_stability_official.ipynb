# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot(x, y, title):
    plt.plot(x, y, 'o')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(title)
    plt.show()

# %% [markdown]
# # Stability plots: increasing events and increasing e- energy
#
# ## Volumetric distribution

# %% [markdown]
# Let's first of all insert all the data obtaining from the simulations:

# %%
#energies 
energies_1000 = [100, 500, 600, 700, 800, 1000] #keV
energies_100000 = [100, 200, 300, 400, 500, 600, 700, 800, 900] #keV
energies = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000] #keV

#data 1000
SSB_1000 = [0.317901,0.456491,0.426465,0.414216,0.459463,0.332617]
SSBp_1000 = [0.00648777,0.0130426,0,0.0285666,0.0417693,0.0151189]
dSSB_1000 = [0,0,0,0.0142833,0.0139231,0]
SSBtotal_1000 = [0.324388,0.469534,0.426465,0.457066,0.515155,0.347736]

DSB_1000 = [0.0194633,0.0130426,0,0.0142833,0.0139231,0]
DSBp_1000 = [0.00648777,0.0130426,0,0,0,0]
DSBpp_1000 = [0,0,0.0142155,0,0,0.0151189]
DSBtotal_1000 = [0.0259511,0.0260852,0.0142155,0.0142833,0.0139231,0.0151189]

SSB_direct_1000  = [0.0583899,0.0391278,0.0426465,0.0571332,0.0139231,0.0453568]
SSB_indirect_1000  = [0.259511,0.417363,0.383819,0.385649,0.473386,0.272141]
SSB_mixed_1000  = [0.00648777,0.0130426,0,0.0142833,0.0278462,0.0302379]

DSB_direct_1000  = [0,0,0,0.0142833,0,0]
DSB_indirect_1000  = [0.0194633,0.0130426,0.0142155,0,0.0139231,0]
DSB_mixed_1000  = [0,0.0130426,0,0,0,0.0151189]
DSB_hybrid_1000  = [0.00648777,0,0,0,0,0]

#data 10000
SSB_10000 = [0.383755,0.411762,0.39834,0.345616,0.354875,0.41486,0.421294,0.358449,0.354398,0.351154]
SSBp_10000 = [0.0268957,0.0232524,0.0229591,0.0225401,0.0171501,0.0137827,0.0256192,0.0199138,0.0174294,0.0175577]
dSSB_10000 = [0.00918389,0.0184082,0.0149234,0.00500892,0.00923467,0.00689136,0.00853974,0.0142242,0.0116196,0.0135059]
SSBtotal_10000 = [0.419835,0.453422,0.436222,0.373165,0.38126,0.435534,0.455453,0.392587,0.383447,0.378166]

DSB_10000 = [0.0183678,0.0125951,0.0172193,0.016279,0.00791543,0.0110262,0.00853974,0.0142242,0.0116196,0.0216095]
DSBp_10000 = [0.00196798,0.0019377,0.00229591,0.00250446,0.00395772,0.00413482,0.00426987,0.00426725,0.00145245,0]
DSBpp_10000 = [0.00196798,0.0019377,0.00114795,0.00250446,0.00263848,0.00413482,0.00142329,0.00142242,0.0029049,0.00135059]
DSBtotal_10000 = [0.0223037,0.0164705,0.0206631,0.0212879,0.0145116,0.0192958,0.0142329,0.0199139,0.015977,0.0229601]

SSB_direct_10000  = [0.0413275,0.0503803,0.0424742,0.0388191,0.0382579,0.0399699,0.0412754,0.0369829,0.0435736,0.0378166]
SSB_indirect_10000  = [0.364075,0.392385,0.379972,0.316814,0.32849,0.388673,0.405638,0.339958,0.323897,0.326843]
dSSB_1000000 = [0.00970346,0.00888687,0.0091376,0.00908412,0.00921845,0.00884035,0.00836126,0.00918684,0.00906199,0.00781374]
SSBtotal_1000000 = [0.406544,0.400377,0.397929,0.400454,0.39899,0.400461,0.394151,0.393805,0.393631,0.374335]

DSB_1000000 = [0.0147585,0.0140545,0.0149373,0.0141727,0.0140012,0.0140249,0.0142713,0.0144641,0.0133626,0.0130363]
DSBp_1000000 = [0.00218344,0.00245767,0.00225113,0.00225889,0.00208283,0.00208712,0.00196095,0.00215511,0.00181519,0.00169163]
DSBpp_1000000 = [0.00200826,0.00176616,0.00163013,0.00173667,0.0017614,0.00175478,0.00206989,0.00161633,0.00201067,0.00163793]
DSBtotal_1000000 = [0.0189502,0.0182784,0.0188186,0.0181682,0.0178455,0.0178668,0.0183022,0.0182355,0.0171885,0.0163659]

SSB_direct_1000000  = [0.0413414,0.0396498,0.0377259,0.0392633,0.0379023,0.039868,0.0384564,0.0384742,0.0383145,0.0385854]
SSB_indirect_1000000  = [0.352922,0.348821,0.348515,0.349411,0.348874,0.348895,0.344746,0.343698,0.343658,0.324458]
SSB_mixed_1000000  = [0.012281,0.0119052,0.0116881,0.0117802,0.0122141,0.0116985,0.0109486,0.0116321,0.0116591,0.011291]

DSB_direct_1000000  = [0.0016016,0.00154189,0.00149706,0.0013359,0.00140141,0.0014889,0.00132092,0.00171304,0.00124271,0.0014634]
DSB_indirect_1000000  = [0.00810812,0.00769074,0.00829481,0.00760249,0.00741847,0.0078832,0.0077757,0.00815073,0.00780532,0.00687394]
DSB_mixed_1000000  = [0.001245,0.00123351,0.00106457,0.00143306,0.00122141,0.00103691,0.001389,0.000828888,0.00114497,0.00103378]
DSB_hybrid_1000000  = [0.0079955,0.00781223,0.00796213,0.0077968,0.00780418,0.0074578,0.00781656,0.00754288,0.00699547,0.00699477]

# %% [markdown]
# ## SSB plot

# %%
#plot near SSB
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('SSB damage with increasing energies, \n internal volume distribution', fontsize = 20)


axs[0, 0].plot(energies_1000, SSB_1000, label='SSB')
axs[0, 0].plot(energies_1000, SSBp_1000, label='SSB+')
axs[0, 0].plot(energies_1000, dSSB_1000, label='double SSB')
axs[0, 0].plot(energies_1000, SSBtotal_1000, label='total SSB')
axs[0, 0].set_title('1000 events', fontsize = 14)
axs[0, 0].legend(fontsize = 10)



axs[0, 1].plot(energies, SSB_10000, label='SSB')
axs[0, 1].plot(energies, SSBp_10000, label='SSB+')
axs[0, 1].plot(energies, dSSB_10000, label='double SSB')
axs[0, 1].plot(energies, SSBtotal_10000, label='total SSB')
axs[0, 1].set_title('10000 events', fontsize = 14)
axs[0, 1].legend(fontsize = 10)


axs[1, 0].plot(energies_100000, SSB_100000, label='SSB')
axs[1, 0].plot(energies_100000, SSBp_100000, label='SSB+')
axs[1, 0].plot(energies_100000, dSSB_100000, label='double SSB')
axs[1, 0].plot(energies_100000, SSBtotal_100000, label='total SSB')
axs[1, 0].set_title('100000 events', fontsize = 14)
axs[1, 0].legend(fontsize = 10)

axs[1, 1].plot(energies, SSB_1000000, label='SSB')
axs[1, 1].plot(energies, SSBp_1000000, label='SSB+')
axs[1, 1].plot(energies, dSSB_1000000, label='double SSB')
axs[1, 1].plot(energies, SSBtotal_1000000, label='total SSB')
axs[1, 1].set_title('1000000 events', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


#set labels
xlabel = 'e- energy (keV)'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)

# Set the filename and format
filename = "SSBDmgVolume_complexity.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')

plt.show()

# %% [markdown]
# ## DSB plot

# %%
#plot near DSB
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('DSB damage with increasing energies, \n internal volume distribution', fontsize = 20)


axs[0, 0].plot(energies_1000, DSB_1000, label='DSB')
axs[0, 0].plot(energies_1000, DSBp_1000, label='DSB+')
axs[0, 0].plot(energies_1000, DSBpp_1000, label='DSB++')
axs[0, 0].plot(energies_1000, DSBtotal_1000, label='total DSB')
axs[0, 0].set_title('1000 events', fontsize = 14)
axs[0, 0].legend(fontsize = 10)


axs[0, 1].plot(energies, DSB_10000, label='DSB')
axs[0, 1].plot(energies, DSBp_10000, label='DSB+')
axs[0, 1].plot(energies, DSBpp_10000, label='DSB++')
axs[0, 1].plot(energies, DSBtotal_10000, label='total DSB')
axs[0, 1].set_title('10000 events', fontsize = 14)
axs[0, 1].legend(fontsize = 10)


axs[1, 0].plot(energies_100000, DSB_100000, label='DSB')
axs[1, 0].plot(energies_100000, DSBp_100000, label='DSB+')
axs[1, 0].plot(energies_100000, DSBpp_100000, label='DSB++')
axs[1, 0].plot(energies_100000, DSBtotal_100000, label='total DSB')
axs[1, 0].set_title('100000 events', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


axs[1, 1].plot(energies, DSB_1000000, label='DSB')
axs[1, 1].plot(energies, DSBp_1000000, label='DSB+')
axs[1, 1].plot(energies, DSBpp_1000000, label='DSB++')
axs[1, 1].plot(energies, DSBtotal_1000000, label='total DSB')
axs[1, 1].set_title('1000000 events', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


#set labels
xlabel = 'e- energy (keV)'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)

# Set the filename and format
filename = "DSBDmgVolume_complexity.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Damage source plot for SSB

# %%
#plot near SSB direct/indirect
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('SSB source damage with increasing energies, \n internal volume distribution', fontsize = 20)


axs[0, 0].plot(energies_1000, SSB_direct_1000, label='Direct SSB')
axs[0, 0].plot(energies_1000, SSB_indirect_1000, label='Indirect SSB')
axs[0, 0].plot(energies_1000, SSB_mixed_1000, label='Mixed SSB')
axs[0, 0].set_title('1000 events', fontsize = 14)
axs[0, 0].legend(fontsize = 10)


axs[0, 1].plot(energies, SSB_direct_10000, label='Direct SSB')
axs[0, 1].plot(energies, SSB_indirect_10000, label='Indirect SSB')
axs[0, 1].plot(energies, SSB_mixed_10000, label='Mixed SSB')
axs[0, 1].set_title('100000 events', fontsize = 14)
axs[0, 1].legend(fontsize = 10)


axs[1, 0].plot(energies_100000, SSB_direct_100000, label='Direct SSB')
axs[1, 0].plot(energies_100000, SSB_indirect_100000, label='Indirect SSB')
axs[1, 0].plot(energies_100000, SSB_mixed_100000, label='Mixed SSB')
axs[1, 0].set_title('100000 events', fontsize = 14)
axs[1, 0].legend(fontsize = 10)


axs[1, 1].plot(energies, SSB_direct_1000000, label='Direct SSB')
axs[1, 1].plot(energies, SSB_indirect_1000000, label='Indirect SSB')
axs[1, 1].plot(energies, SSB_mixed_1000000, label='Mixed SSB')
axs[1, 1].set_title('1000000 events', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


#set labels
xlabel = 'e- energy (keV)'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)



# Set the filename and format
filename = "SSBDmgVolume.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')


plt.show()

# %% [markdown]
# ## Damage source plot for DSB

# %%
#plot near DSB direct/indirect
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('DSB source damage with increasing energies, \n internal volume distribution', fontsize = 20)


axs[0, 0].plot(energies_1000, DSB_direct_1000, label='Direct DSB')
axs[0, 0].plot(energies_1000, DSB_indirect_1000, label='Indirect DSB')
axs[0, 0].plot(energies_1000, DSB_mixed_1000, label='Mixed DSB')
axs[0, 0].plot(energies_1000, DSB_hybrid_1000, label='Hybrid DSB')
axs[0, 0].set_title('1000 events', fontsize = 14)
axs[0, 0].legend(fontsize = 10)


axs[0, 1].plot(energies, DSB_direct_10000, label='Direct DSB')
axs[0, 1].plot(energies, DSB_indirect_10000, label='Indirect DSB')
axs[0, 1].plot(energies, DSB_mixed_10000, label='Mixed DSB')
axs[0, 1].plot(energies, DSB_hybrid_10000, label='Hybrid DSB')
axs[0, 1].set_title('100000 events', fontsize = 14)
axs[0, 1].legend(fontsize = 10)


axs[1, 0].plot(energies_100000, DSB_direct_100000, label='Direct DSB')
axs[1, 0].plot(energies_100000, DSB_indirect_100000, label='Indirect DSB')
axs[1, 0].plot(energies_100000, DSB_mixed_100000, label='Mixed DSB')
axs[1, 0].plot(energies_100000, DSB_hybrid_100000, label='Hybrid DSB')
axs[1, 0].set_title('100000 events', fontsize = 14)
axs[1, 0].legend(fontsize = 10)


axs[1, 1].plot(energies, DSB_direct_1000000, label='Direct DSB')
axs[1, 1].plot(energies, DSB_indirect_1000000, label='Indirect DSB')
axs[1, 1].plot(energies, DSB_mixed_1000000, label='Mixed DSB')
axs[1, 1].plot(energies, DSB_hybrid_1000000, label='Hybrid DSB')
axs[1, 1].set_title('1000000 events', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


#set labels
xlabel = 'e- energy (keV)'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)

# Set the filename and format
filename = "DSBDmgVolume.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')

plt.show()

# %% [markdown]
# # Stability plots: increasing events and increasing e- energy
#
# ## Superficial distribution

# %%
#energies 
energies_1000 = [100, 500, 600, 700, 800, 1000] #keV
energies_100000 = [100, 200, 300, 400, 500, 600, 700, 800, 900] #keV
energies = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000] #keV

#data 1000
SSB_1000 = [0.358561,0.407508,0.33878,0.327019,0.318689,0.418563,0.411177,0.345209,0.331716,0.332065]
SSBp_1000 = [0.0270612,0.00515832,0.0114841,0.0327019,0.0207841,0.0216498,0.0228431,0.00784565,0.0552859,0.0154449]
dSSB_1000 = [0.0135306,0.0206333,0.0114841,0.0261615,0,0.0072166,0.0152288,0.00784565,0.015796,0]
SSBtotal_1000 = [0.399153,0.433299,0.361748,0.385882,0.339473,0.447429,0.449248,0.3609,0.402798,0.34751]

DSB_1000 = [0.00676531,0.0103166,0.0172261,0.0130808,0.00692803,0.0216498,0.0152288,0,0.00789799,0]
DSBp_1000 = [0,0,0,0.00654038,0,0,0.00761438,0.00784565,0.00789799,0.00772245]
DSBpp_1000 = [0.00338265,0.0103166,0.00574203,0.00654038,0.00692803,0,0,0.0156913,0,0]
DSBtotal_1000 = [0.010148,0.0206333,0.0229681,0.0261615,0.0138561,0.0216498,0.0228431,0.023537,0.015796,0.00772245]

SSB_direct_1000  = [0.0338265,0.0257916,0.0401942,0.0261615,0.0415682,0.0505162,0.0456863,0.0392282,0.0473879,0.0231673]
SSB_direct_1000000  = [0.042172,0.0408223,0.0402387,0.0396075,0.0415526,0.0404802,0.0405475,0.03996,0.0404206,0.0393892]
SSB_indirect_1000000  = [0.360428,0.360376,0.356296,0.363685,0.361799,0.362387,0.358164,0.357506,0.359326,0.348705]
SSB_mixed_1000000  = [0.0126474,0.0121276,0.0123204,0.0119557,0.0125194,0.0123154,0.0119739,0.0117992,0.0121262,0.0112732]

DSB_direct_1000000  = [0.00153933,0.0015042,0.00143508,0.0015239,0.001564,0.0015004,0.00169273,0.00161078,0.00137141,0.00143377]
DSB_indirect_1000000  = [0.00840388,0.00822088,0.00831596,0.00784807,0.00805498,0.00808081,0.00847144,0.00779998,0.00790768,0.00801177]
DSB_mixed_1000000  = [0.00124463,0.00130573,0.00112175,0.00119834,0.00117484,0.00109674,0.00112328,0.00138067,0.00124309,0.0011029]
DSB_hybrid_1000000  = [0.00808839,0.00790228,0.0082157,0.00796582,0.00774659,0.00779139,0.00776158,0.00774443,0.00784352,0.00785421]

# %% [markdown]
# ## SSB plot

# %%
#plot near SSB
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('SSB damage with increasing energies, \n superficial distribution', fontsize = 20)


axs[0, 0].plot(energies, SSB_1000, label='SSB')
axs[0, 0].plot(energies, SSBp_1000, label='SSB+')
axs[0, 0].plot(energies, dSSB_1000, label='double SSB')
axs[0, 0].plot(energies, SSBtotal_1000, label='total SSB')
axs[0, 0].set_title('1000 events', fontsize = 14)
axs[0, 0].legend(fontsize = 10)


axs[0, 1].plot(energies, SSB_10000, label='SSB')
axs[0, 1].plot(energies, SSBp_10000, label='SSB+')
axs[0, 1].plot(energies, dSSB_10000, label='double SSB')
axs[0, 1].plot(energies, SSBtotal_10000, label='total SSB')
axs[0, 1].set_title('10000 events', fontsize = 14)
axs[0, 1].legend(fontsize = 10)


axs[1, 0].plot(energies, SSB_100000, label='SSB')
axs[1, 0].plot(energies, SSBp_100000, label='SSB+')
axs[1, 0].plot(energies, dSSB_100000, label='double SSB')
axs[1, 0].plot(energies, SSBtotal_100000, label='total SSB')
axs[1, 0].set_title('100000 events', fontsize = 14)
axs[1, 0].legend(fontsize = 10)

axs[1, 1].plot(energies, SSB_1000000, label='SSB')
axs[1, 1].plot(energies, SSBp_1000000, label='SSB+')
axs[1, 1].plot(energies, dSSB_1000000, label='double SSB')
axs[1, 1].plot(energies, SSBtotal_1000000, label='total SSB')
axs[1, 1].set_title('1000000 events', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


#set labels
xlabel = 'e- energy (keV)'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)

# Set the filename and format
filename = "SSBDmgSup_complexity.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')

plt.show()

# %% [markdown]
# ## DSB plot

# %%
#plot near DSB
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('DSB damage with increasing energies, \n superficial distribution', fontsize = 20)


axs[0, 0].plot(energies, DSB_1000, label='DSB')
axs[0, 0].plot(energies, DSBp_1000, label='DSB+')
axs[0, 0].plot(energies, DSBpp_1000, label='DSB++')
axs[0, 0].plot(energies, DSBtotal_1000, label='total DSB')
axs[0, 0].set_title('1000 events', fontsize = 14)
axs[0, 0].legend(fontsize = 10)


axs[0, 1].plot(energies, DSB_10000, label='DSB')
axs[0, 1].plot(energies, DSBp_10000, label='DSB+')
axs[0, 1].plot(energies, DSBpp_10000, label='DSB++')
axs[0, 1].plot(energies, DSBtotal_10000, label='total DSB')
axs[0, 1].set_title('10000 events', fontsize = 14)
axs[0, 1].legend(fontsize = 10)


axs[1, 0].plot(energies, DSB_100000, label='DSB')
axs[1, 0].plot(energies, DSBp_100000, label='DSB+')
axs[1, 0].plot(energies, DSBpp_100000, label='DSB++')
axs[1, 0].plot(energies, DSBtotal_100000, label='total DSB')
axs[1, 0].set_title('100000 events', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


axs[1, 1].plot(energies, DSB_1000000, label='DSB')
axs[1, 1].plot(energies, DSBp_1000000, label='DSB+')
axs[1, 1].plot(energies, DSBpp_1000000, label='DSB++')
axs[1, 1].plot(energies, DSBtotal_1000000, label='total DSB')
axs[1, 1].set_title('1000000 events', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


#set labels
xlabel = 'e- energy (keV)'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)

# Set the filename and format
filename = "DSBDmgSup_complexity.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## SSB plot damage source

# %%
#plot near SSB direct/indirect
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('SSB source damage with increasing energies, \n superficial distribution', fontsize = 20)


axs[0, 0].plot(energies, SSB_direct_1000, label='Direct SSB')
axs[0, 0].plot(energies, SSB_indirect_1000, label='Indirect SSB')
axs[0, 0].plot(energies, SSB_mixed_1000, label='Mixed SSB')
axs[0, 0].set_title('1000 events', fontsize = 14)
axs[0, 0].legend(fontsize = 10)


axs[0, 1].plot(energies, SSB_direct_10000, label='Direct SSB')
axs[0, 1].plot(energies, SSB_indirect_10000, label='Indirect SSB')
axs[0, 1].plot(energies, SSB_mixed_10000, label='Mixed SSB')
axs[0, 1].set_title('100000 events', fontsize = 14)
axs[0, 1].legend(fontsize = 10)


axs[1, 0].plot(energies, SSB_direct_100000, label='Direct SSB')
axs[1, 0].plot(energies, SSB_indirect_100000, label='Indirect SSB')
axs[1, 0].plot(energies, SSB_mixed_100000, label='Mixed SSB')
axs[1, 0].set_title('100000 events', fontsize = 14)
axs[1, 0].legend(fontsize = 10)


axs[1, 1].plot(energies, SSB_direct_1000000, label='Direct SSB')
axs[1, 1].plot(energies, SSB_indirect_1000000, label='Indirect SSB')
axs[1, 1].plot(energies, SSB_mixed_1000000, label='Mixed SSB')
axs[1, 1].set_title('1000000 events', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


#set labels
xlabel = 'e- energy (keV)'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)



# Set the filename and format
filename = "SSBDmgSup.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')


plt.show()

# %% [markdown]
# ## DSB plot damage source

# %%
#plot near DSB direct/indirect
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('DSB source damage with increasing energies, \n superficial distribution', fontsize = 20)


axs[0, 0].plot(energies, DSB_direct_1000, label='Direct DSB')
axs[0, 0].plot(energies, DSB_indirect_1000, label='Indirect DSB')
axs[0, 0].plot(energies, DSB_mixed_1000, label='Mixed DSB')
axs[0, 0].plot(energies, DSB_hybrid_1000, label='Hybrid DSB')
axs[0, 0].set_title('1000 events', fontsize = 14)
axs[0, 0].legend(fontsize = 10)


axs[0, 1].plot(energies, DSB_direct_10000, label='Direct DSB')
axs[0, 1].plot(energies, DSB_indirect_10000, label='Indirect DSB')
axs[0, 1].plot(energies, DSB_mixed_10000, label='Mixed DSB')
axs[0, 1].plot(energies, DSB_hybrid_10000, label='Hybrid DSB')
axs[0, 1].set_title('100000 events', fontsize = 14)
axs[0, 1].legend(fontsize = 10)


axs[1, 0].plot(energies, DSB_direct_100000, label='Direct DSB')
axs[1, 0].plot(energies, DSB_indirect_100000, label='Indirect DSB')
axs[1, 0].plot(energies, DSB_mixed_100000, label='Mixed DSB')
axs[1, 0].plot(energies, DSB_hybrid_100000, label='Hybrid DSB')
axs[1, 0].set_title('100000 events', fontsize = 14)
axs[1, 0].legend(fontsize = 10)


axs[1, 1].plot(energies, DSB_direct_1000000, label='Direct DSB')
axs[1, 1].plot(energies, DSB_indirect_1000000, label='Indirect DSB')
axs[1, 1].plot(energies, DSB_mixed_1000000, label='Mixed DSB')
axs[1, 1].plot(energies, DSB_hybrid_1000000, label='Hybrid DSB')
axs[1, 1].set_title('1000000 events', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


#set labels
xlabel = 'e- energy (keV)'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)

# Set the filename and format
filename = "DSBDmgSup.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')

plt.show()

# %% [markdown]
# ## Let's now plot datasets about the same variable with different number of events

# %%
#plot near SSB
# Create the figure and 4 subplots
fig, axs = plt.subplots(2, 2, figsize = (16,14))
fig.suptitle('Damage with increasing events, \n superficial distribution', fontsize = 20)


axs[0, 0].plot(energies, SSBtotal_1000, label='1e3')
axs[0, 0].plot(energies, SSBtotal_10000, label='1e4')
axs[0, 0].plot(energies, SSBtotal_100000, label='1e5')
axs[0, 0].plot(energies, SSBtotal_1000000, label='1e6')
axs[0, 0].set_title('SSB', fontsize = 14)
axs[0, 0].legend(fontsize = 10)


axs[0, 1].plot(energies, DSBtotal_1000, label='1e3')
axs[0, 1].plot(energies, DSBtotal_10000, label='1e4')
axs[0, 1].plot(energies, DSBtotal_100000, label='1e5')
axs[0, 1].plot(energies, DSBtotal_1000000, label='1e6')
axs[0, 1].set_title('DSB', fontsize = 14)
axs[0, 1].legend(fontsize = 10)


axs[1, 0].plot(energies, np.add(SSB_direct_1000 , DSB_direct_1000), label='1e3')
axs[1, 0].plot(energies, np.add(SSB_direct_10000 , DSB_direct_10000) , label='1e4')
axs[1, 0].plot(energies, np.add(SSB_direct_100000 , DSB_direct_100000), label='1e5')
axs[1, 0].plot(energies, np.add(SSB_direct_1000000 , DSB_direct_1000000), label='1e6')
axs[1, 0].set_title('Total direct damage', fontsize = 14)
axs[1, 0].legend(fontsize = 10)

axs[1, 1].plot(energies, np.add(SSB_indirect_1000 , DSB_indirect_1000), label='1e3')
axs[1, 1].plot(energies, np.add(SSB_indirect_10000 , DSB_indirect_10000) , label='1e4')
axs[1, 1].plot(energies, np.add(SSB_indirect_100000 , DSB_indirect_100000), label='1e5')
axs[1, 1].plot(energies, np.add(SSB_indirect_1000000 , DSB_indirect_1000000), label='1e6')
axs[1, 1].set_title('Total indirect damage', fontsize = 14)
axs[1, 1].legend(fontsize = 10)


#set labels
xlabel = 'e- energy (keV)'
ylabel = 'Damage yield (Gy-1 Mbp-1) '

# set x and y labels for each axis
axs[0, 0].set_xlabel(xlabel)
axs[0, 0].set_ylabel(ylabel)
axs[0, 1].set_xlabel(xlabel)
axs[0, 1].set_ylabel(ylabel)
axs[1, 1].set_xlabel(xlabel)
axs[1, 1].set_ylabel(ylabel)
axs[1, 0].set_xlabel(xlabel)
axs[1, 0].set_ylabel(ylabel)

# Set the filename and format
filename = "SSBDmgSup_allEventstotal.jpg"
# Save the plot as a JPG file
plt.savefig(filename, format='jpg')

plt.show()
